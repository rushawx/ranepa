# %%
import pandas as pd
import seaborn as sns
import plotly.express as px

# %%
pd.set_option('display.max_columns', None)

# %%
pd.set_option('display.max_rows', 10)

# %%
df = pd.read_csv("Sample - Superstore.csv", encoding="cp1251")

# %%
df.columns
# Out:
# Index(['Row ID', 'Order ID', 'Order Date', 'Ship Date', 'Ship Mode',
#        'Customer ID', 'Customer Name', 'Segment', 'Country', 'City', 'State',
#        'Postal Code', 'Region', 'Product ID', 'Category', 'Sub-Category',
#        'Product Name', 'Sales', 'Quantity', 'Discount', 'Profit'],
#       dtype='object')

# %%
df.head(3)
# Out:
#    Row ID        Order ID Order Date   Ship Date     Ship Mode Customer ID  \
# 0       1  CA-2016-152156  11/8/2016  11/11/2016  Second Class    CG-12520
# 1       2  CA-2016-152156  11/8/2016  11/11/2016  Second Class    CG-12520
# 2       3  CA-2016-138688  6/12/2016   6/16/2016  Second Class    DV-13045
#
#      Customer Name    Segment        Country         City       State  \
# 0      Claire Gute   Consumer  United States    Henderson    Kentucky
# 1      Claire Gute   Consumer  United States    Henderson    Kentucky
# 2  Darrin Van Huff  Corporate  United States  Los Angeles  California
#
#    Postal Code Region       Product ID         Category Sub-Category  \
# 0        42420  South  FUR-BO-10001798        Furniture    Bookcases
# 1        42420  South  FUR-CH-10000454        Furniture       Chairs
# 2        90036   West  OFF-LA-10000240  Office Supplies       Labels
#
#                                         Product Name   Sales  Quantity  \
# ...

# %%
df.tail(3)
# Out:
#       Row ID        Order ID Order Date Ship Date       Ship Mode Customer ID  \
# 9991    9992  CA-2017-121258  2/26/2017  3/3/2017  Standard Class    DB-13060
# 9992    9993  CA-2017-121258  2/26/2017  3/3/2017  Standard Class    DB-13060
# 9993    9994  CA-2017-119914   5/4/2017  5/9/2017    Second Class    CC-12220
#
#      Customer Name   Segment        Country         City       State  \
# 9991   Dave Brooks  Consumer  United States   Costa Mesa  California
# 9992   Dave Brooks  Consumer  United States   Costa Mesa  California
# 9993  Chris Cortes  Consumer  United States  Westminster  California
#
#       Postal Code Region       Product ID         Category Sub-Category  \
# 9991        92627   West  TEC-PH-10003645       Technology       Phones
# 9992        92627   West  OFF-PA-10004041  Office Supplies        Paper
# 9993        92683   West  OFF-AP-10002684  Office Supplies   Appliances
#
#                                            Product Name    Sales  Quantity  \
# ...

# %%
df.sample(3)
# Out:
#       Row ID        Order ID  Order Date   Ship Date       Ship Mode  \
# 1771    1772  CA-2016-129686  11/27/2016  11/29/2016    Second Class
# 7721    7722  CA-2015-108588    1/5/2015   1/10/2015  Standard Class
# 5797    5798  CA-2014-124856   9/29/2014   10/3/2014    Second Class
#
#      Customer ID      Customer Name    Segment        Country           City  \
# 1771    GG-14650       Greg Guthrie  Corporate  United States        Chicago
# 7721    BG-11695  Brooke Gillingham  Corporate  United States  New York City
# 5797    LD-17005     Lisa DeCherney   Consumer  United States  New York City
#
#          State  Postal Code   Region       Product ID         Category  \
# 1771  Illinois        60623  Central  OFF-ST-10004337  Office Supplies
# 7721  New York        10009     East  OFF-BI-10004506  Office Supplies
# 5797  New York        10011     East  OFF-LA-10000121  Office Supplies
#
#      Sub-Category                                       Product Name   Sales  \
# ...

# %%
df.shape
# Out:
# (9994, 21)

# %%
# df = df.drop(columns=["Row ID"], inplace=False)

# %%
df.drop(columns=["Row ID"], inplace=True)

# %%
df.head()
# Out:
#          Order ID  Order Date   Ship Date       Ship Mode Customer ID  \
# 0  CA-2016-152156   11/8/2016  11/11/2016    Second Class    CG-12520
# 1  CA-2016-152156   11/8/2016  11/11/2016    Second Class    CG-12520
# 2  CA-2016-138688   6/12/2016   6/16/2016    Second Class    DV-13045
# 3  US-2015-108966  10/11/2015  10/18/2015  Standard Class    SO-20335
# 4  US-2015-108966  10/11/2015  10/18/2015  Standard Class    SO-20335
#
#      Customer Name    Segment        Country             City       State  \
# 0      Claire Gute   Consumer  United States        Henderson    Kentucky
# 1      Claire Gute   Consumer  United States        Henderson    Kentucky
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  California
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale     Florida
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale     Florida
#
#    Postal Code Region       Product ID         Category Sub-Category  \
# ...

# %%
df["Order ID"]
# Out:
# 0       CA-2016-152156
# 1       CA-2016-152156
# 2       CA-2016-138688
# 3       US-2015-108966
# 4       US-2015-108966
#              ...
# 9989    CA-2014-110422
# 9990    CA-2017-121258
# 9991    CA-2017-121258
# 9992    CA-2017-121258
# 9993    CA-2017-119914
# Name: Order ID, Length: 9994, dtype: object

# %%
df[["Order ID", "Country", "State", "City", "Sales"]].head()
# Out:
#          Order ID        Country       State             City     Sales
# 0  CA-2016-152156  United States    Kentucky        Henderson  261.9600
# 1  CA-2016-152156  United States    Kentucky        Henderson  731.9400
# 2  CA-2016-138688  United States  California      Los Angeles   14.6200
# 3  US-2015-108966  United States     Florida  Fort Lauderdale  957.5775
# 4  US-2015-108966  United States     Florida  Fort Lauderdale   22.3680

# %%
df[(df["State"] == "Florida")].head()
# Out:
#            Order ID  Order Date   Ship Date       Ship Mode Customer ID  \
# 3    US-2015-108966  10/11/2015  10/18/2015  Standard Class    SO-20335
# 4    US-2015-108966  10/11/2015  10/18/2015  Standard Class    SO-20335
# 43   CA-2017-139619   9/19/2017   9/23/2017  Standard Class    ES-14080
# 231  US-2017-100930    4/7/2017   4/12/2017  Standard Class    CS-12400
# 232  US-2017-100930    4/7/2017   4/12/2017  Standard Class    CS-12400
#
#           Customer Name      Segment        Country             City    State  \
# 3        Sean O'Donnell     Consumer  United States  Fort Lauderdale  Florida
# 4        Sean O'Donnell     Consumer  United States  Fort Lauderdale  Florida
# 43           Erin Smith    Corporate  United States        Melbourne  Florida
# 231  Christopher Schild  Home Office  United States            Tampa  Florida
# 232  Christopher Schild  Home Office  United States            Tampa  Florida
#
# ...

# %%
df[(df["State"] == "Florida") & (df["Category"] == "Furniture")].head()
# Out:
#            Order ID  Order Date   Ship Date       Ship Mode Customer ID  \
# 3    US-2015-108966  10/11/2015  10/18/2015  Standard Class    SO-20335
# 231  US-2017-100930    4/7/2017   4/12/2017  Standard Class    CS-12400
# 232  US-2017-100930    4/7/2017   4/12/2017  Standard Class    CS-12400
# 234  US-2017-100930    4/7/2017   4/12/2017  Standard Class    CS-12400
# 384  US-2015-168935  11/27/2015   12/2/2015  Standard Class    DO-13435
#
#           Customer Name      Segment        Country             City    State  \
# 3        Sean O'Donnell     Consumer  United States  Fort Lauderdale  Florida
# 231  Christopher Schild  Home Office  United States            Tampa  Florida
# 232  Christopher Schild  Home Office  United States            Tampa  Florida
# 234  Christopher Schild  Home Office  United States            Tampa  Florida
# 384        Denny Ordway     Consumer  United States   Pembroke Pines  Florida
#
# ...

# %%
df[
    (df["State"] == "Florida") & 
    (df["Category"].isin(["Furniture", "Office Supplies"]))
    ] \
    .sample(5)
# Out:
#             Order ID  Order Date   Ship Date       Ship Mode Customer ID  \
# 8234  CA-2017-102204    5/1/2017    5/6/2017  Standard Class    CJ-12010
# 5488  CA-2017-134495    4/1/2017    4/4/2017    Second Class    BF-11020
# 4801  US-2016-148901   5/14/2016   5/19/2016  Standard Class    MK-17905
# 8822  CA-2017-100622   11/3/2017   11/7/2017  Standard Class    DK-13090
# 3769  CA-2014-153913  12/16/2014  12/20/2014    Second Class    KB-16585
#
#           Customer Name    Segment        Country          City    State  \
# 8234    Caroline Jumper   Consumer  United States  Jacksonville  Florida
# 5488  Barry Franzцsisch  Corporate  United States  Jacksonville  Florida
# 4801    Michael Kennedy  Corporate  United States  Jacksonville  Florida
# 8822          Dave Kipp   Consumer  United States       Orlando  Florida
# 3769          Ken Black  Corporate  United States       Hialeah  Florida
#
#       Postal Code Region       Product ID         Category Sub-Category  \
# ...

# %%
df.groupby(by=["Country", "State", "City"]).agg({"Sales": ["min", "mean", "max"]})
# Out:
#                                        Sales
#                                          min         mean       max
# Country       State     City
# United States Alabama   Auburn         3.760   294.471667   900.080
#                         Decatur       14.940   259.601538  1215.920
#                         Florence       4.980   399.470000  1819.860
#                         Hoover         7.160   131.462500   477.240
#                         Huntsville     3.620   248.437000  1319.960
# ...                                      ...          ...       ...
#               Wisconsin Superior       5.560   144.414444   629.100
#                         Waukesha      54.500    54.500000    54.500
#                         Wausau        12.390    79.370000   245.880
#                         West Allis     8.520   125.240000   241.960
#               Wyoming   Cheyenne    1603.136  1603.136000  1603.136
#
# [604 rows x 3 columns]

# %%
df.groupby(by=["Country", "State", "City"]).agg({"Sales": ["min", "mean", "max"]}).reset_index(drop=False)
# Out:
#            Country      State        City     Sales
#                                                 min         mean       max
# 0    United States    Alabama      Auburn     3.760   294.471667   900.080
# 1    United States    Alabama     Decatur    14.940   259.601538  1215.920
# 2    United States    Alabama    Florence     4.980   399.470000  1819.860
# 3    United States    Alabama      Hoover     7.160   131.462500   477.240
# 4    United States    Alabama  Huntsville     3.620   248.437000  1319.960
# ..             ...        ...         ...       ...          ...       ...
# 599  United States  Wisconsin    Superior     5.560   144.414444   629.100
# 600  United States  Wisconsin    Waukesha    54.500    54.500000    54.500
# 601  United States  Wisconsin      Wausau    12.390    79.370000   245.880
# 602  United States  Wisconsin  West Allis     8.520   125.240000   241.960
# 603  United States    Wyoming    Cheyenne  1603.136  1603.136000  1603.136
#
# ...

# %%
dfg = df.groupby(by=["Country", "State", "City"]).agg({"Sales": ["min", "mean", "max"]}).reset_index()
dfg.columns = ["Country", "State", "City", "Sales Min", "Sales Mean", "Sales Max"]

# %%
dfg[["State", "City", "Sales Mean"]]
# Out:
#          State        City   Sales Mean
# 0      Alabama      Auburn   294.471667
# 1      Alabama     Decatur   259.601538
# 2      Alabama    Florence   399.470000
# 3      Alabama      Hoover   131.462500
# 4      Alabama  Huntsville   248.437000
# ..         ...         ...          ...
# 599  Wisconsin    Superior   144.414444
# 600  Wisconsin    Waukesha    54.500000
# 601  Wisconsin      Wausau    79.370000
# 602  Wisconsin  West Allis   125.240000
# 603    Wyoming    Cheyenne  1603.136000
#
# [604 rows x 3 columns]

# %%
dfg.sort_values(by=["Sales Mean"], ascending=[False])
# Out:
#            Country       State          City  Sales Min   Sales Mean  \
# 384  United States    New York     Jamestown    159.980  2354.395000
# 233  United States     Indiana     Lafayette      5.780  1635.870833
# 603  United States     Wyoming      Cheyenne   1603.136  1603.136000
# 574  United States  Washington    Bellingham     25.120  1263.413333
# 331  United States    Missouri  Independence    839.430  1208.685000
# ..             ...         ...           ...        ...          ...
# 163  United States     Florida  Ormond Beach      2.808     2.808000
# 166  United States     Florida     Pensacola      2.214     2.214000
# 154  United States     Florida       Jupiter      2.064     2.064000
# 425  United States        Ohio        Elyria      1.824     1.824000
# 494  United States       Texas       Abilene      1.392     1.392000
#
#      Sales Max
# 384   4548.810
# 233  17499.950
# 603   1603.136
# 574   2665.620
# 331   1577.940
# ..         ...
# 163      2.808
# ...

# %%
dfg.sort_values(by=["Sales Mean"], ascending=[False]).reset_index(drop=True)
# Out:
#            Country       State          City  Sales Min   Sales Mean  \
# 0    United States    New York     Jamestown    159.980  2354.395000
# 1    United States     Indiana     Lafayette      5.780  1635.870833
# 2    United States     Wyoming      Cheyenne   1603.136  1603.136000
# 3    United States  Washington    Bellingham     25.120  1263.413333
# 4    United States    Missouri  Independence    839.430  1208.685000
# ..             ...         ...           ...        ...          ...
# 599  United States     Florida  Ormond Beach      2.808     2.808000
# 600  United States     Florida     Pensacola      2.214     2.214000
# 601  United States     Florida       Jupiter      2.064     2.064000
# 602  United States        Ohio        Elyria      1.824     1.824000
# 603  United States       Texas       Abilene      1.392     1.392000
#
#      Sales Max
# 0     4548.810
# 1    17499.950
# 2     1603.136
# 3     2665.620
# 4     1577.940
# ..         ...
# 599      2.808
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 20 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Order ID       9994 non-null   object
#  1   Order Date     9994 non-null   object
#  2   Ship Date      9994 non-null   object
#  3   Ship Mode      9994 non-null   object
#  4   Customer ID    9994 non-null   object
#  5   Customer Name  9994 non-null   object
#  6   Segment        9994 non-null   object
#  7   Country        9994 non-null   object
#  8   City           9994 non-null   object
#  9   State          9994 non-null   object
#  10  Postal Code    9994 non-null   int64
#  11  Region         9994 non-null   object
#  12  Product ID     9994 non-null   object
#  13  Category       9994 non-null   object
#  14  Sub-Category   9994 non-null   object
#  15  Product Name   9994 non-null   object
#  16  Sales          9994 non-null   float64
# ...

# %%
df.describe()
# Out:
#         Postal Code         Sales     Quantity     Discount       Profit
# count   9994.000000   9994.000000  9994.000000  9994.000000  9994.000000
# mean   55190.379428    229.858001     3.789574     0.156203    28.656896
# std    32063.693350    623.245101     2.225110     0.206452   234.260108
# min     1040.000000      0.444000     1.000000     0.000000 -6599.978000
# 25%    23223.000000     17.280000     2.000000     0.000000     1.728750
# 50%    56430.500000     54.490000     3.000000     0.200000     8.666500
# 75%    90008.000000    209.940000     5.000000     0.200000    29.364000
# max    99301.000000  22638.480000    14.000000     0.800000  8399.976000

# %%
df.describe(include="all")
# Out:
#               Order ID Order Date   Ship Date       Ship Mode Customer ID  \
# count             9994       9994        9994            9994        9994
# unique            5009       1237        1334               4         793
# top     CA-2017-100111   9/5/2016  12/16/2015  Standard Class    WB-21850
# freq                14         38          35            5968          37
# mean               NaN        NaN         NaN             NaN         NaN
# ...                ...        ...         ...             ...         ...
# min                NaN        NaN         NaN             NaN         NaN
# 25%                NaN        NaN         NaN             NaN         NaN
# 50%                NaN        NaN         NaN             NaN         NaN
# 75%                NaN        NaN         NaN             NaN         NaN
# max                NaN        NaN         NaN             NaN         NaN
#
#         Customer Name   Segment        Country           City       State  \
# ...

# %%
df.head()
# Out:
#          Order ID  Order Date   Ship Date       Ship Mode Customer ID  \
# 0  CA-2016-152156   11/8/2016  11/11/2016    Second Class    CG-12520
# 1  CA-2016-152156   11/8/2016  11/11/2016    Second Class    CG-12520
# 2  CA-2016-138688   6/12/2016   6/16/2016    Second Class    DV-13045
# 3  US-2015-108966  10/11/2015  10/18/2015  Standard Class    SO-20335
# 4  US-2015-108966  10/11/2015  10/18/2015  Standard Class    SO-20335
#
#      Customer Name    Segment        Country             City       State  \
# 0      Claire Gute   Consumer  United States        Henderson    Kentucky
# 1      Claire Gute   Consumer  United States        Henderson    Kentucky
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  California
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale     Florida
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale     Florida
#
#    Postal Code Region       Product ID         Category Sub-Category  \
# ...

# %%
df["Order Date"] = pd.to_datetime(df["Order Date"], format="%m/%d/%Y")
df["Ship Date"] = pd.to_datetime(df["Ship Date"], format="%m/%d/%Y")

# %%
df["Postal Code"] = df["Postal Code"].astype(str)

# %%
df.head()
# Out:
#          Order ID Order Date  Ship Date       Ship Mode Customer ID  \
# 0  CA-2016-152156 2016-11-08 2016-11-11    Second Class    CG-12520
# 1  CA-2016-152156 2016-11-08 2016-11-11    Second Class    CG-12520
# 2  CA-2016-138688 2016-06-12 2016-06-16    Second Class    DV-13045
# 3  US-2015-108966 2015-10-11 2015-10-18  Standard Class    SO-20335
# 4  US-2015-108966 2015-10-11 2015-10-18  Standard Class    SO-20335
#
#      Customer Name    Segment        Country             City       State  \
# 0      Claire Gute   Consumer  United States        Henderson    Kentucky
# 1      Claire Gute   Consumer  United States        Henderson    Kentucky
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  California
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale     Florida
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale     Florida
#
#   Postal Code Region       Product ID         Category Sub-Category  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 20 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Order ID       9994 non-null   object
#  1   Order Date     9994 non-null   datetime64[ns]
#  2   Ship Date      9994 non-null   datetime64[ns]
#  3   Ship Mode      9994 non-null   object
#  4   Customer ID    9994 non-null   object
#  5   Customer Name  9994 non-null   object
#  6   Segment        9994 non-null   object
#  7   Country        9994 non-null   object
#  8   City           9994 non-null   object
#  9   State          9994 non-null   object
#  10  Postal Code    9994 non-null   object
#  11  Region         9994 non-null   object
#  12  Product ID     9994 non-null   object
#  13  Category       9994 non-null   object
#  14  Sub-Category   9994 non-null   object
#  15  Product Name   9994 non-null   object
#  16  Sales          9994 non-null   float64
# ...

# %%
help(df.describe)
# Out:
# Help on method describe in module pandas.core.generic:
#
# describe(percentiles=None, include=None, exclude=None) -> Self method of pandas.core.frame.DataFrame instance
#     Generate descriptive statistics.
#
#     Descriptive statistics include those that summarize the central
#     tendency, dispersion and shape of a
#     dataset's distribution, excluding ``NaN`` values.
#
#     Analyzes both numeric and object series, as well
#     as ``DataFrame`` column sets of mixed data types. The output
#     will vary depending on what is provided. Refer to the notes
#     below for more detail.
#
#     Parameters
#     ----------
#     percentiles : list-like of numbers, optional
#         The percentiles to include in the output. All should
#         fall between 0 and 1. The default is
#         ``[.25, .5, .75]``, which returns the 25th, 50th, and
#         75th percentiles.
#     include : 'all', list-like of dtypes or None (default), optional
# ...

# %%
df.describe(include=[float, int])
# Out:
#               Sales     Quantity     Discount       Profit
# count   9994.000000  9994.000000  9994.000000  9994.000000
# mean     229.858001     3.789574     0.156203    28.656896
# std      623.245101     2.225110     0.206452   234.260108
# min        0.444000     1.000000     0.000000 -6599.978000
# 25%       17.280000     2.000000     0.000000     1.728750
# 50%       54.490000     3.000000     0.200000     8.666500
# 75%      209.940000     5.000000     0.200000    29.364000
# max    22638.480000    14.000000     0.800000  8399.976000

# %%
df["Sales w/o VAT"] = df.apply(lambda x: x["Sales"] / 1.2, axis=1)

# %%
df.head()
# Out:
#          Order ID Order Date  Ship Date       Ship Mode Customer ID  \
# 0  CA-2016-152156 2016-11-08 2016-11-11    Second Class    CG-12520
# 1  CA-2016-152156 2016-11-08 2016-11-11    Second Class    CG-12520
# 2  CA-2016-138688 2016-06-12 2016-06-16    Second Class    DV-13045
# 3  US-2015-108966 2015-10-11 2015-10-18  Standard Class    SO-20335
# 4  US-2015-108966 2015-10-11 2015-10-18  Standard Class    SO-20335
#
#      Customer Name    Segment        Country             City       State  \
# 0      Claire Gute   Consumer  United States        Henderson    Kentucky
# 1      Claire Gute   Consumer  United States        Henderson    Kentucky
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  California
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale     Florida
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale     Florida
#
#   Postal Code Region       Product ID         Category Sub-Category  \
# ...

# %%
df["Segment"].nunique()
# Out:
# 3

# %%
df["Segment"].unique()
# Out:
# array(['Consumer', 'Corporate', 'Home Office'], dtype=object)

# %%
df["Segment"].value_counts()
# Out:
# Segment
# Consumer       5191
# Corporate      3020
# Home Office    1783
# Name: count, dtype: int64

# %%
df["Segment"].value_counts(normalize=True)
# Out:
# Segment
# Consumer       0.519412
# Corporate      0.302181
# Home Office    0.178407
# Name: proportion, dtype: float64

# %%
dir(df)
# Out:
# ['Category',
#  'City',
#  'Country',
#  'Discount',
#  'Profit',
#  'Quantity',
#  'Region',
#  'Sales',
#  'Segment',
#  'State',
#  'T',
#  '_AXIS_LEN',
#  '_AXIS_ORDERS',
#  '_AXIS_TO_AXIS_NUMBER',
#  '_HANDLED_TYPES',
#  '__abs__',
#  '__add__',
#  '__and__',
#  '__annotations__',
#  '__array__',
#  '__array_priority__',
#  '__array_ufunc__',
#  '__arrow_c_stream__',
#  '__bool__',
#  '__class__',
#  '__contains__',
#  '__copy__',
#  '__dataframe__',
#  '__dataframe_consortium_standard__',
#  '__deepcopy__',
#  '__delattr__',
#  '__delitem__',
#  '__dict__',
#  '__dir__',
#  '__divmod__',
#  '__doc__',
#  '__eq__',
#  '__finalize__',
#  '__firstlineno__',
#  '__floordiv__',
#  '__format__',
#  '__ge__',
#  '__getattr__',
#  '__getattribute__',
#  '__getitem__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__iadd__',
#  '__iand__',
#  '__ifloordiv__',
#  '__imod__',
#  '__imul__',
#  '__init__',
#  '__init_subclass__',
#  '__invert__',
#  '__ior__',
#  '__ipow__',
# ...

# %%
df["Sales w/o VAT"].sum()
# Out:
# np.float64(1914334.0502499999)

# %%
df["Sales w/o VAT"].mean()
# Out:
# np.float64(191.54833402541524)

# %%
df["Sales w/o VAT"].min()
# Out:
# np.float64(0.37)

# %%
df["Sales w/o VAT"].max()
# Out:
# np.float64(18865.4)

# %%
df["Sales w/o VAT"].quantile(0.5)
# Out:
# np.float64(45.40833333333333)

# %%
df["Sales w/o VAT"].quantile(0.25)
# Out:
# np.float64(14.400000000000002)

# %%
df["Sales w/o VAT"].quantile(0.75)
# Out:
# np.float64(174.95000000000002)

# %%
df["Sales w/o VAT"].var()
# Out:
# np.float64(269746.149519497)

# %%
df["Sales w/o VAT"].std()
# Out:
# np.float64(519.3709170905673)

# %%
df["Sales w/o VAT"].to_list()
# Out:
# [218.29999999999998,
#  609.95,
#  12.183333333333334,
#  797.98125,
#  18.64,
#  40.71666666666667,
#  6.066666666666667,
#  755.96,
#  15.420000000000002,
#  95.75000000000001,
#  1421.82,
#  759.52,
#  12.96,
#  339.98,
#  57.34166666666667,
#  2.12,
#  554.9,
#  46.25,
#  7.133333333333334,
#  177.9,
#  18.933333333333334,
#  16.21666666666667,
#  50.28333333333334,
#  59.47666666666667,
#  870.5250000000001,
#  9.706666666666667,
#  75.475,
#  2569.525,
#  8.015,
#  103.5,
#  2.7199999999999998,
#  71.92,
#  5.715,
#  13.133333333333333,
#  24.560000000000002,
#  914.6200000000001,
#  159.1,
#  94.44000000000001,
#  443.666,
#  176.715,
#  309.3066666666667,
#  122.64000000000001,
#  64.9,
#  79.68,
#  38.31666666666666,
#  14.55,
#  176.63333333333335,
#  37.5,
#  18.166666666666668,
#  31.85,
#  62.650000000000006,
#  5.133333333333334,
#  74.99166666666666,
#  12.716666666666667,
#  858.2916666666667,
#  173.8,
#  27.0,
#  266.175,
#  12.133333333333335,
#  25.0,
#  40.4,
# ...

# %%
df[["Order ID", "Sales w/o VAT"]].to_dict(index="orient").keys()
# Out:
# dict_keys(['Order ID', 'Sales w/o VAT'])

# %%
df[["Order ID", "Sales w/o VAT"]].to_dict(index="orient")
# Out:
# {'Order ID': {0: 'CA-2016-152156',
#   1: 'CA-2016-152156',
#   2: 'CA-2016-138688',
#   3: 'US-2015-108966',
#   4: 'US-2015-108966',
#   5: 'CA-2014-115812',
#   6: 'CA-2014-115812',
#   7: 'CA-2014-115812',
#   8: 'CA-2014-115812',
#   9: 'CA-2014-115812',
#   10: 'CA-2014-115812',
#   11: 'CA-2014-115812',
#   12: 'CA-2017-114412',
#   13: 'CA-2016-161389',
#   14: 'US-2015-118983',
#   15: 'US-2015-118983',
#   16: 'CA-2014-105893',
#   17: 'CA-2014-167164',
#   18: 'CA-2014-143336',
#   19: 'CA-2014-143336',
#   20: 'CA-2014-143336',
#   21: 'CA-2016-137330',
#   22: 'CA-2016-137330',
#   23: 'US-2017-156909',
#   24: 'CA-2015-106320',
#   25: 'CA-2016-121755',
#   26: 'CA-2016-121755',
#   27: 'US-2015-150630',
#   28: 'US-2015-150630',
#   29: 'US-2015-150630',
#   30: 'US-2015-150630',
#   31: 'US-2015-150630',
#   32: 'US-2015-150630',
#   33: 'US-2015-150630',
#   34: 'CA-2017-107727',
#   35: 'CA-2016-117590',
#   36: 'CA-2016-117590',
#   37: 'CA-2015-117415',
# ...

# %%
help(df.to_dict)
# Out:
# Help on method to_dict in module pandas.core.frame:
#
# to_dict(
#     orient: Literal['dict', 'list', 'series', 'split', 'tight', 'records', 'index'] = 'dict',
#     *,
#     into: type[MutableMappingT] | MutableMappingT = <class 'dict'>,
#     index: bool = True
# ) -> MutableMappingT | list[MutableMappingT] method of pandas.core.frame.DataFrame instance
#     Convert the DataFrame to a dictionary.
#
#     The type of the key-value pairs can be customized with the parameters
#     (see below).
#
#     Parameters
#     ----------
#     orient : str {'dict', 'list', 'series', 'split', 'tight', 'records', 'index'}
#         Determines the type of the values of the dictionary.
#
#         - 'dict' (default) : dict like {column -> {index -> value}}
#         - 'list' : dict like {column -> [values]}
#         - 'series' : dict like {column -> Series(values)}
#         - 'split' : dict like
#           {'index' -> [index], 'columns' -> [columns], 'data' -> [values]}
# ...

# %%
df.rename(columns={"Order ID": "OrderID"})
# Out:
#              OrderID Order Date  Ship Date       Ship Mode Customer ID  \
# 0     CA-2016-152156 2016-11-08 2016-11-11    Second Class    CG-12520
# 1     CA-2016-152156 2016-11-08 2016-11-11    Second Class    CG-12520
# 2     CA-2016-138688 2016-06-12 2016-06-16    Second Class    DV-13045
# 3     US-2015-108966 2015-10-11 2015-10-18  Standard Class    SO-20335
# 4     US-2015-108966 2015-10-11 2015-10-18  Standard Class    SO-20335
# ...              ...        ...        ...             ...         ...
# 9989  CA-2014-110422 2014-01-21 2014-01-23    Second Class    TB-21400
# 9990  CA-2017-121258 2017-02-26 2017-03-03  Standard Class    DB-13060
# 9991  CA-2017-121258 2017-02-26 2017-03-03  Standard Class    DB-13060
# 9992  CA-2017-121258 2017-02-26 2017-03-03  Standard Class    DB-13060
# 9993  CA-2017-119914 2017-05-04 2017-05-09    Second Class    CC-12220
#
#          Customer Name    Segment        Country             City       State  \
# ...

# %%
df.head()
# Out:
#          Order ID Order Date  Ship Date       Ship Mode Customer ID  \
# 0  CA-2016-152156 2016-11-08 2016-11-11    Second Class    CG-12520
# 1  CA-2016-152156 2016-11-08 2016-11-11    Second Class    CG-12520
# 2  CA-2016-138688 2016-06-12 2016-06-16    Second Class    DV-13045
# 3  US-2015-108966 2015-10-11 2015-10-18  Standard Class    SO-20335
# 4  US-2015-108966 2015-10-11 2015-10-18  Standard Class    SO-20335
#
#      Customer Name    Segment        Country             City       State  \
# 0      Claire Gute   Consumer  United States        Henderson    Kentucky
# 1      Claire Gute   Consumer  United States        Henderson    Kentucky
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  California
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale     Florida
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale     Florida
#
#   Postal Code Region       Product ID         Category Sub-Category  \
# ...

# %%
df.iloc[:10, 1:5]
# Out:
#   Order Date  Ship Date       Ship Mode Customer ID
# 0 2016-11-08 2016-11-11    Second Class    CG-12520
# 1 2016-11-08 2016-11-11    Second Class    CG-12520
# 2 2016-06-12 2016-06-16    Second Class    DV-13045
# 3 2015-10-11 2015-10-18  Standard Class    SO-20335
# 4 2015-10-11 2015-10-18  Standard Class    SO-20335
# 5 2014-06-09 2014-06-14  Standard Class    BH-11710
# 6 2014-06-09 2014-06-14  Standard Class    BH-11710
# 7 2014-06-09 2014-06-14  Standard Class    BH-11710
# 8 2014-06-09 2014-06-14  Standard Class    BH-11710
# 9 2014-06-09 2014-06-14  Standard Class    BH-11710

# %%
df.loc[:10, ["Order ID", "Customer ID"]]
# Out:
#           Order ID Customer ID
# 0   CA-2016-152156    CG-12520
# 1   CA-2016-152156    CG-12520
# 2   CA-2016-138688    DV-13045
# 3   US-2015-108966    SO-20335
# 4   US-2015-108966    SO-20335
# ..             ...         ...
# 6   CA-2014-115812    BH-11710
# 7   CA-2014-115812    BH-11710
# 8   CA-2014-115812    BH-11710
# 9   CA-2014-115812    BH-11710
# 10  CA-2014-115812    BH-11710
#
# [11 rows x 2 columns]

# %%
df.where(df["Sales"] < 10, 42).sample(50)
# Out:
#             Order ID           Order Date            Ship Date  \
# 4073              42                   42                   42
# 188               42                   42                   42
# 5583  CA-2014-116673  2014-12-15 00:00:00  2014-12-19 00:00:00
# 8922              42                   42                   42
# 4411              42                   42                   42
# ...              ...                  ...                  ...
# 7141              42                   42                   42
# 6422              42                   42                   42
# 8865              42                   42                   42
# 5680  CA-2016-141551  2016-09-24 00:00:00  2016-09-30 00:00:00
# 565               42                   42                   42
#
#            Ship Mode Customer ID       Customer Name   Segment        Country  \
# 4073              42          42                  42        42             42
# ...

# %%
help(df.where)
# Out:
# Help on method where in module pandas.core.generic:
#
# where(
#     cond,
#     other=nan,
#     *,
#     inplace: bool_t = False,
#     axis: Axis | None = None,
#     level: Level | None = None
# ) -> Self | None method of pandas.core.frame.DataFrame instance
#     Replace values where the condition is False.
#
#     Parameters
#     ----------
#     cond : bool Series/DataFrame, array-like, or callable
#         Where `cond` is True, keep the original value. Where
#         False, replace with corresponding value from `other`.
#         If `cond` is callable, it is computed on the Series/DataFrame and
#         should return boolean Series/DataFrame or array. The callable must
#         not change input Series/DataFrame (though pandas doesn't check it).
#     other : scalar, Series/DataFrame, or callable
#         Entries where `cond` is False are replaced with
#         corresponding value from `other`.
#         If other is callable, it is computed on the Series/DataFrame and
# ...

# %%
df["Sales"].hist()
# Out:
# <Axes: >

# %%
sns.histplot(df, x="Sales")
# Out:
# <Axes: xlabel='Sales', ylabel='Count'>

# %%
sns.boxplot(df, x="Sales")
# Out:
# <Axes: xlabel='Sales'>

# %%
sns.histplot(df, x="Quantity")
# Out:
# <Axes: xlabel='Quantity', ylabel='Count'>

# %%
df["Quantity"].median()
# Out:
# np.float64(3.0)

# %%
df["Quantity"].mean()
# Out:
# np.float64(3.789573744246548)

# %%
sns.boxplot(df, x="Quantity")
# Out:
# <Axes: xlabel='Quantity'>

# %%
sns.boxplot(df, y="Quantity")
# Out:
# <Axes: ylabel='Quantity'>

# %%
sns.boxplot(df, y="Quantity", hue="Category")
# Out:
# <Axes: ylabel='Quantity'>

# %%
df["Year"] = df["Order Date"].apply(lambda x: x.year)

# %%
df.head()
# Out:
#          Order ID Order Date  Ship Date       Ship Mode Customer ID  \
# 0  CA-2016-152156 2016-11-08 2016-11-11    Second Class    CG-12520
# 1  CA-2016-152156 2016-11-08 2016-11-11    Second Class    CG-12520
# 2  CA-2016-138688 2016-06-12 2016-06-16    Second Class    DV-13045
# 3  US-2015-108966 2015-10-11 2015-10-18  Standard Class    SO-20335
# 4  US-2015-108966 2015-10-11 2015-10-18  Standard Class    SO-20335
#
#      Customer Name    Segment        Country             City       State  \
# 0      Claire Gute   Consumer  United States        Henderson    Kentucky
# 1      Claire Gute   Consumer  United States        Henderson    Kentucky
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  California
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale     Florida
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale     Florida
#
#   Postal Code Region       Product ID         Category Sub-Category  \
# ...

# %%
data = df.groupby(by=["Order Date"]).agg({"Sales w/o VAT": "sum"}).reset_index()

# %%
data.head()
# Out:
#   Order Date  Sales w/o VAT
# 0 2014-01-03      13.706667
# 1 2014-01-04     240.050000
# 2 2014-01-05      16.280000
# 3 2014-01-06    3672.583333
# 4 2014-01-07      72.631667

# %%
sns.lineplot(data, x="Order Date", y="Sales w/o VAT")
# Out:
# <Axes: xlabel='Order Date', ylabel='Sales w/o VAT'>

# %%
ydata = df.groupby(by=["Year"]).agg({"Sales w/o VAT": "sum"}).reset_index()

# %%
ydata.head()
# Out:
#    Year  Sales w/o VAT
# 0  2014  403539.581750
# 1  2015  392110.424167
# 2  2016  507671.331667
# 3  2017  611012.712667

# %%
sns.lineplot(ydata, x="Year", y="Sales w/o VAT")
# Out:
# <Axes: xlabel='Year', ylabel='Sales w/o VAT'>

# %%
sns.barplot(ydata, x="Year", y="Sales w/o VAT")
# Out:
# <Axes: xlabel='Year', ylabel='Sales w/o VAT'>

# %%
ycdata = df.groupby(by=["Year", "Category"]).agg({"Sales w/o VAT": "sum"}).reset_index()

# %%
ycdata.head()
# Out:
#    Year         Category  Sales w/o VAT
# 0  2014        Furniture  130994.044250
# 1  2014  Office Supplies  126480.343333
# 2  2014       Technology  146065.194167
# 3  2015        Furniture  142098.530833
# 4  2015  Office Supplies  114361.219167

# %%
help(sns.barplot)
# Out:
# Help on function barplot in module seaborn.categorical:
#
# barplot(
#     data=None,
#     *,
#     x=None,
#     y=None,
#     hue=None,
#     order=None,
#     hue_order=None,
#     estimator='mean',
#     errorbar=('ci', 95),
#     n_boot=1000,
#     seed=None,
#     units=None,
#     weights=None,
#     orient=None,
#     color=None,
#     palette=None,
#     saturation=0.75,
#     fill=True,
#     hue_norm=None,
#     width=0.8,
#     dodge='auto',
#     gap=0,
#     log_scale=None,
#     native_scale=False,
#     formatter=None,
#     legend='auto',
#     capsize=0,
#     err_kws=None,
#     ci=<deprecated>,
#     errcolor=<deprecated>,
#     errwidth=<deprecated>,
#     ax=None,
#     **kwargs
# )
#     Show point estimates and errors as rectangular bars.
#
#     A bar plot represents an aggregate or statistical estimate for a numeric
#     variable with the height of each rectangle and indicates the uncertainty
# ...

# %%
sns.barplot(ycdata, x="Year", y="Sales w/o VAT", hue="Category")
# Out:
# <Axes: xlabel='Year', ylabel='Sales w/o VAT'>

# %%
sns.scatterplot(df, x="Sales w/o VAT", y="Quantity")
# Out:
# <Axes: xlabel='Sales w/o VAT', ylabel='Quantity'>

# %%
help(df.corr)
# Out:
# Help on method corr in module pandas.core.frame:
#
# corr(
#     method: CorrelationMethod = 'pearson',
#     min_periods: int = 1,
#     numeric_only: bool = False
# ) -> DataFrame method of pandas.core.frame.DataFrame instance
#     Compute pairwise correlation of columns, excluding NA/null values.
#
#     Parameters
#     ----------
#     method : {'pearson', 'kendall', 'spearman'} or callable
#         Method of correlation:
#
#         * pearson : standard correlation coefficient
#         * kendall : Kendall Tau correlation coefficient
#         * spearman : Spearman rank correlation
#         * callable: callable with input two 1d ndarrays
#             and returning a float. Note that the returned matrix from corr
#             will have 1 along the diagonals and will be symmetric
#             regardless of the callable's behavior.
#     min_periods : int, optional
#         Minimum number of observations required per pair of columns
# ...

# %%
df.drop(columns=["Year"], inplace=True)

# %%
abs(df.corr(numeric_only=True))
# Out:
#                   Sales  Quantity  Discount    Profit  Sales w/o VAT
# Sales          1.000000  0.200795  0.028190  0.479064       1.000000
# Quantity       0.200795  1.000000  0.008623  0.066253       0.200795
# Discount       0.028190  0.008623  1.000000  0.219487       0.028190
# Profit         0.479064  0.066253  0.219487  1.000000       0.479064
# Sales w/o VAT  1.000000  0.200795  0.028190  0.479064       1.000000

# %%
sns.heatmap(abs(df.corr(numeric_only=True)), annot=True, cmap="crest")
# Out:
# <Axes: >

# %%
sns.pairplot(df)

# %%
px.bar(ycdata, x="Year", y="Sales w/o VAT", color="Category", barmode="stack")

# %%
px.line(data, x="Order Date", y="Sales w/o VAT")

# %%
px.histogram(df, x="Sales w/o VAT", nbins=50)

# %%
px.pie(df, names="Category", values="Sales w/o VAT")

# %%
px.sunburst(df, path=["Category", "Sub-Category"], values="Sales w/o VAT", title="Sales w/o VAT by Category and Sub-Category")

# %%
data = dict(
    number=[39, 27.4, 20.6, 11, 2],
    stage=["Website visit", "Downloads", "Potential customers", "Requested price", "invoice sent"]
    )

# %%
px.funnel(data, x='number', y='stage')
